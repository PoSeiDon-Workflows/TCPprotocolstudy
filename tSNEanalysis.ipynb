# %%
#Importing useful libraries

from __future__ import print_function
import time
import numpy as np
import pandas as pd
#from sklearn.datasets import fetch_mldata
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
# %matplotlib inline
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns


#load datasets
cubic_elep_norm_df= pd.read_csv('processedfiles/cubicnormalele.csv')
cubic_elep_loss01_df=pd.read_csv('processedfiles/cubicloss01ele.csv')
cubic_elep_loss05_df=pd.read_csv('processedfiles/cubicloss05ele.csv')
cubic_elep_loss1_df=pd.read_csv('processedfiles/cubicloss1ele.csv')
cubic_elep_dup1_df=pd.read_csv('processedfiles/cubicduplicate1ele.csv')
cubic_elep_dup5_df=pd.read_csv('processedfiles/cubicduplicate5ele.csv')
cubic_elep_re25_df=pd.read_csv('processedfiles/cubicreorder25ele.csv')
cubic_elep_re50_df=pd.read_csv('processedfiles/cubicreorder50ele.csv')


reno_elep_norm_df= pd.read_csv('processedfiles/renonormalele.csv')
reno_elep_loss01_df=pd.read_csv('processedfiles/renoloss01ele.csv')
reno_elep_loss05_df=pd.read_csv('processedfiles/renoloss05ele.csv')
reno_elep_loss1_df=pd.read_csv('processedfiles/renoloss1ele.csv')
reno_elep_dup1_df=pd.read_csv('processedfiles/renoduplicate1ele.csv')
reno_elep_dup5_df=pd.read_csv('processedfiles/renoduplicate5ele.csv')
reno_elep_re25_df=pd.read_csv('processedfiles/renoreorder25ele.csv')
reno_elep_re50_df=pd.read_csv('processedfiles/renoreorder50ele.csv')


ham_elep_norm_df= pd.read_csv('processedfiles/hamnormalele.csv')
ham_elep_loss01_df=pd.read_csv('processedfiles/hamloss01ele.csv')
ham_elep_loss05_df=pd.read_csv('processedfiles/hamloss05ele.csv')
ham_elep_loss1_df=pd.read_csv('processedfiles/hamloss1ele.csv')
ham_elep_dup1_df=pd.read_csv('processedfiles/hamduplicate1ele.csv')
ham_elep_dup5_df=pd.read_csv('processedfiles/hamduplicate5ele.csv')
ham_elep_re25_df=pd.read_csv('processedfiles/hamreorder25ele.csv')
ham_elep_re50_df=pd.read_csv('processedfiles/hamreorder50ele.csv')


bbr_elep_norm_df= pd.read_csv('processedfiles/bbrnormalele.csv')
bbr_elep_loss01_df=pd.read_csv('processedfiles/bbrloss01ele.csv')
bbr_elep_loss05_df=pd.read_csv('processedfiles/bbrloss05ele.csv')
bbr_elep_loss1_df=pd.read_csv('processedfiles/bbrloss1ele.csv')
bbr_elep_dup1_df=pd.read_csv('processedfiles/bbrduplicate1ele.csv')
bbr_elep_dup5_df=pd.read_csv('processedfiles/bbrduplicate5ele.csv')
bbr_elep_re25_df=pd.read_csv('processedfiles/bbrreorder25ele.csv')
bbr_elep_re50_df=pd.read_csv('processedfiles/bbrreorder50ele.csv')


#add all dataframes into one
cubic_elep_norm_df['target']='0'
reno_elep_norm_df['target']='1'
ham_elep_norm_df['target']='2'
bbr_elep_norm_df['target']='3'

#print(cubic_elep_norm_df)

df_list=[cubic_elep_norm_df,reno_elep_norm_df,ham_elep_norm_df,bbr_elep_norm_df]

merged=pd.concat(df_list)

print(merged.shape)
print(merged)

# %%
merged = merged.drop(columns=['#15#c_ip:1','c_port:2','s_ip:15','s_port:16','first:29','last:30',
                              'http_res:113','c_tls_SNI:116','s_tls_SCN:117', 'fqdn:127','dns_rslv:128'])

merged.dropna(inplace=True)
#drop the target column to prevent bias
y=merged['target']
merged = merged.drop(columns=['target'])

print(merged.shape)
print(merged)

# %%
tsne_em = TSNE(n_components=2, perplexity=30.0, n_iter=1000, verbose=1).fit_transform(merged)

# %%
#plot a 2D graphs

pca = PCA(n_components=2)
pca_result = pca.fit_transform(merged)

res_col = ["target", "pca-2d-one", "pca-2d-two", "tsne-2d-one", "tsne-2d-two"]
results = pd.DataFrame(columns = res_col)
results["target"] = y

results['pca-2d-one'] = pca_result[:,0]
results['pca-2d-two'] = pca_result[:,1] 
print('Explained variation per principal component: {}'.format(pca.explained_variance_ratio_))


# t-SNE implementation, 2D - Dimentionality reduced to 2
tsne = TSNE(n_components=2, verbose=1, perplexity=40, n_iter=300)
tsne_results = tsne.fit_transform(merged)

results['tsne-2d-one'] = tsne_results[:,0]
results['tsne-2d-two'] = tsne_results[:,1]

# %%
# plotting PCA vs t-SNE in 2D

plt.figure(figsize=(16,7))
ax1 = plt.subplot(1, 2, 1)
sns.scatterplot(
    x="pca-2d-one", y="pca-2d-two",
    hue="target",
    palette=sns.color_palette("bright", 4),
    data=results,
    legend="full",
    alpha=0.3,
    ax=ax1
)
ax2 = plt.subplot(1, 2, 2)
sns.scatterplot(
    x="tsne-2d-one", y="tsne-2d-two",
    hue="target",
    palette=sns.color_palette("bright", 4),
    data=results,
    legend="full",
    alpha=0.3,
    ax=ax2
)

# %%
# plotting PCA vs t-SNE in 3D
# plotting PCA vs t-SNE in 3D

pca = PCA(n_components=3)
pca_result = pca.fit_transform(merged)

res_col = ["target", "pca-3d-one", "pca-3d-two","pca-3d-three", "tsne-3d-one", "tsne-3d-two", "tsne-3d-three"]
results = pd.DataFrame(columns = res_col)
results["target"] = y

results['pca-3d-one'] = pca_result[:,0]
results['pca-3d-two'] = pca_result[:,1] 
results['pca-3d-three'] = pca_result[:,2] 
print('Explained variation per principal component: {}'.format(pca.explained_variance_ratio_))

# t-SNE implementation, 2D - Dimentionality reduced to 3
tsne = TSNE(n_components=3, verbose=1, perplexity=40, n_iter=300)
tsne_results = tsne.fit_transform(merged)

results['tsne-2d-one'] = tsne_results[:,0]
results['tsne-2d-two'] = tsne_results[:,1]
results['tsne-3d-three'] = tsne_results[:,2]

# plotting PCA 3D
fig = plt.figure(figsize=(18,7))
    
ax = fig.add_subplot(1,2,1, projection='3d')
scatter = ax.scatter(
    xs=results['pca-3d-one'], 
    ys=results['pca-3d-two'], 
    zs=results['pca-3d-three'], 
    c=results['target'], 
    cmap='Accent'
)

ax.set_xlabel('pca-3d-one')
ax.set_ylabel('pca-3d-two')
ax.set_zlabel('pca-3d-three')
legend1 = ax.legend(*scatter.legend_elements(), loc="lower left", title="target")
#plt.scatter(x, y, labels='RESULT')

ax.add_artist(legend1)


# plotting t-SNE 3D

ax = fig.add_subplot(1,2,2, projection='3d')
scatter = ax.scatter(
    xs=results['tsne-3d-one'], 
    ys=results['tsne-3d-two'], 
    zs=results['tsne-3d-three'], 
    c=results['target'], 
    cmap='Accent'
)
legend2 = ax.legend(*scatter.legend_elements(), loc="lower left", title="target")
#plt.scatter(x, y, labels='RESULT')

#leneg#legend2 = ax.legend(*scatter.legend_elements(), loc="lower left", title="target")
ax.add_artist(legend2)
 
ax.set_xlabel('tsne-3d-one')
ax.set_ylabel('tsne-3d-two')
ax.set_zlabel('tsne-3d-three')
ax.set_xlim([-10,10])
ax.set_ylim([-10,10])
ax.set_zlim([-10,10])
    
ax.xaxis.set_ticks(np.arange(-10, 10, 3))
ax.yaxis.set_ticks(np.arange(-10, 10, 3))
ax.zaxis.set_ticks(np.arange(-10, 10, 3))
    
ax.xaxis.set_tick_params(labelsize=14)
ax.yaxis.set_tick_params(labelsize=14)
ax.zaxis.set_tick_params(labelsize=14)
plt.show()
